# %%
import torch
import numpy as np

# %%
torch.tensor([1,2,3,4], dtype=torch.float32)
# Out:
# tensor([1., 2., 3., 4.])

# %%
torch.randint(1, 11, size=(2,3))
# Out:
# tensor([[ 2,  6,  1],
#         [10,  4,  1]])

# %%
torch.randn( size=(2,3) )
torch.randn( 2,3 )
# Out:
# tensor([[ 6.0504e-01,  2.0852e-01, -2.0264e-05],
#         [-1.4951e+00,  1.0377e+00, -3.6734e-01]])

# %%
t1 = torch.arange(1,16).reshape(3,5)
